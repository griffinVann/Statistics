# %% [markdown]
# # List and Tuples <hr style = "border:2.5px solid rgba(119, 65, 65, 1)"></hr>

# %% [markdown]
# <b> Griffin Vann L. Dymosco</b>
# <br> Computer Engineer Tech Student

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
fruit = ['apple', 'banana', 'grape']
fruit
# Out:
# ['apple', 'banana', 'grape']

# %%
mixed_list = [10,'Angel',2.4,True ]
mixed_list
# Out:
# [10, 'Angel', 2.4, True]

# %% [markdown]
# # INDEXING

# %%
numbers = [1,2,3,4,5]
numbers[0]
# Out:
# 1

# %% [markdown]
# # MODIFYING ELEMENTS

# %%
fruit[0] = "Angel"
fruit
# Out:
# ['Angel', 'banana', 'grape']

# %%
fruit[0] = "Apple"
fruit
# Out:
# ['Apple', 'banana', 'grape']

# %% [markdown]
# # ADDING ELEMENTS

# %%
fruit.append("orange")
fruit
# Out:
# ['Apple', 'banana', 'grape', 'orange']

# %%
fruit.insert(1,"Angel")
fruit
# Out:
# ['Apple', 'Angel', 'banana', 'grape', 'orange']

# %% [markdown]
# # REMOVING ELEMENTS

# %%
fruit.remove("Angel")
fruit
# Out:
# ['Apple', 'banana', 'grape', 'orange']

# %%
"Apple" in fruit
# Out:
# True

# %%
"Angel" in fruit
# Out:
# False

# %%
fruit.pop(0)
fruit
# Out:
# ['banana', 'grape', 'orange']

# %% [markdown]
# # SORT() AND SORTED()

# %%
number=[4,3,5,2,1]
number
# Out:
# [4, 3, 5, 2, 1]

# %%
number.sort()
number
# Out:
# [1, 2, 3, 4, 5]

# %%
sorted(numbers)
numbers
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # SLICING

# %%
chars = ['A','N','G','E','L']
chars
# Out:
# ['A', 'N', 'G', 'E', 'L']

# %%
len(chars)
chars
# Out:
# ['A', 'N', 'G', 'E', 'L']

# %%
chars[0:3]
# Out:
# ['A', 'N', 'G']

# %%
sub = chars[0:6:2]
sub
# Out:
# ['A', 'G', 'L']

# %% [markdown]
# # TUPLE

# %%
my_tuple = (1,2,3,4,5,)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[1:3]
# Out:
# (2, 3)
